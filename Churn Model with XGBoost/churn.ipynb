# %%
# Import packages
import pandas as pd
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
import optuna
import warnings
warnings.filterwarnings("ignore")

# %%
# Load data
df = pd.read_csv("train.csv")
df.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# 1             41.38              121.2              110             10.30
# 2             50.90               61.9               88              5.26
# 3             28.34              148.3              122             12.61
# 4             37.09              348.5              108             29.62
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                254.4                103               11.45
# 1                162.6                104                7.32
# 2                196.9                 89                8.86
# 3                186.9                121                8.41
# 4                212.6                118                9.57
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                13.7                 3               3.70
# 1                12.2                 5               3.29
# 2                 6.6                 7               1.78
# 3                10.1                 3               2.73
# 4                 7.5                 7               2.03
#
#    number_customer_service_calls churn
# 0                              1    no
# 1                              0    no
# 2                              2    no
# 3                              3    no
# 4                              3    no

# %%
# Encode target variable
df["churn"] = df["churn"].replace(("yes", "no"), (1, 0))
data = df.drop(["churn"], axis = 1)
target = df["churn"]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.2, random_state = 0)

# %%
# Define categorical and numerical features
categorical_columns = list(X_train.select_dtypes(include = ["object"]).columns.values.tolist())
numeric_columns = list(X_train.select_dtypes(exclude = ["object"]).columns.values.tolist())

# %%
# Create feature engineering pipeline functions
def get_total_net_minutes(df):
    df["total_net_minutes"] = df["total_day_minutes"] + df["total_eve_minutes"] + df["total_night_minutes"]
    return df

def get_total_net_calls(df):
    df["total_net_calls"] = df["total_day_calls"] + df["total_eve_calls"] + df["total_night_calls"]
    return df

def get_total_net_charge(df):
    df["total_net_charge"] = df["total_day_charge"] + df["total_eve_charge"] + df["total_night_charge"]
    return df

def cs_calls_per_month(df):
    df["cs_calls_per_month"] = (df["number_customer_service_calls"] + df["number_vmail_messages"]) / df["account_length"]
    return df

# %%
# Create a feature engineering pipeline with ColumnTransformer
feature_engineering = ColumnTransformer([
    ("total_net_minutes", FunctionTransformer(get_total_net_minutes, validate = False), ["total_day_minutes", "total_eve_minutes", "total_night_minutes"]),
    ("total_net_calls", FunctionTransformer(get_total_net_calls, validate = False), ["total_day_calls", "total_eve_calls", "total_night_calls"]),
    ("total_net_charge", FunctionTransformer(get_total_net_charge, validate = False), ["total_day_charge", "total_eve_charge", "total_night_charge"]),
    ("cs_calls_per_month", FunctionTransformer(cs_calls_per_month, validate = False), ["account_length", "number_customer_service_calls", "number_vmail_messages"]),
])

# %%
# Create a numerical and categorical pipeline
numeric_transformer = SimpleImputer(strategy = "constant")

categorical_transformer = Pipeline(steps = [("imputer", SimpleImputer(strategy = "constant", fill_value = "missing")),
                                        ("onehot", OneHotEncoder(handle_unknown = "ignore"))])

# %%
# Create a feature selection and scaling pipeline
feature_selection = Pipeline(steps = [("scaler", StandardScaler()),
                                      ("feature_selection", SelectFromModel(estimator = LogisticRegression(), threshold = "median"))])

# %%
# Create a preprocessing pipeline
preprocessor = ColumnTransformer(transformers = [("feature_engineering", feature_engineering, numeric_columns),
                                                 ("numeric_transformers", numeric_transformer, numeric_columns),
                                                 ("categorical_transformers", categorical_transformer, categorical_columns)])

# %%
# Create model using XGBClassifier
model = XGBClassifier(random_state = 0)
pipeline = Pipeline(steps = [("preprocessor", preprocessor), ("feature_selection", feature_selection), ("model", model)])

# %%
pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)

# %%
# Evaluate model’s performance
print("Accuracy:", round(accuracy_score(y_test, predictions), 3))
print("AUC:", round(roc_auc_score(y_test, predictions), 3))
# Out:
# Accuracy: 0.973
# AUC: 0.907

# %%
# Use Optuna to tune XGBClassifier hyperparameters
def objective(trial):
    params = {
        "model__n_estimators": trial.suggest_int("model__n_estimators", 100, 1000),
        "model__learning_rate": trial.suggest_float("model__learning_rate", 0.01, 0.1),
        "model__max_depth": trial.suggest_int("model__max_depth", 3, 10),
        "model__min_child_weight": trial.suggest_int("model__min_child_weight", 1, 10),
        "model__gamma": trial.suggest_float("model__gamma", 0.01, 0.1),
        "model__subsample": trial.suggest_float("model__subsample", 0.01, 1.0),
        "model__colsample_bytree": trial.suggest_float("model__colsample_bytree", 0.01, 1.0),
        "model__reg_alpha": trial.suggest_float("model__reg_alpha", 1e-5, 10.0),
        "model__reg_lambda": trial.suggest_float("model__reg_lambda", 1e-5, 10.0),
        "model__scale_pos_weight": trial.suggest_float("model__scale_pos_weight", 1e-5, 10.0),
        "model__n_jobs": 4
    }
    pipeline.set_params(**params)
    pipeline.fit(X_train, y_train)
    predictions = pipeline.predict(X_test)
    return roc_auc_score(y_test, predictions)

# %%
# Run Optuna optimization
study = optuna.create_study(study_name = "churn model", direction = "maximize")
study.optimize(objective, n_trials = 100)
# Out:
# [I 2024-03-28 15:39:13,361] A new study created in memory with name: churn model
# [I 2024-03-28 15:39:13,720] Trial 0 finished with value: 0.9073351079562261 and parameters: {'model__n_estimators': 112, 'model__learning_rate': 0.035815274973332374, 'model__max_depth': 8, 'model__min_child_weight': 2, 'model__gamma': 0.04980012760623743, 'model__subsample': 0.9769556709989113, 'model__colsample_bytree': 0.8417523479445749, 'model__reg_alpha': 7.084635734791159, 'model__reg_lambda': 3.463898830347577, 'model__scale_pos_weight': 1.9063737860998413}. Best is trial 0 with value: 0.9073351079562261.
# [I 2024-03-28 15:39:14,092] Trial 1 finished with value: 0.9126293995859214 and parameters: {'model__n_estimators': 447, 'model__learning_rate': 0.09198336912572205, 'model__max_depth': 4, 'model__min_child_weight': 7, 'model__gamma': 0.071007003741068, 'model__subsample': 0.9205010937146388, 'model__colsample_bytree': 0.36183792024365, 'model__reg_alpha': 5.560445223367975, 'model__reg_lambda': 0.6063121367125471, 'model__scale_pos_weight': 3.6605461432314796}. Best is trial 1 with value: 0.9126293995859214.
# [I 2024-03-28 15:39:14,507] Trial 2 finished with value: 0.9073351079562261 and parameters: {'model__n_estimators': 781, 'model__learning_rate': 0.038159957566493916, 'model__max_depth': 4, 'model__min_child_weight': 8, 'model__gamma': 0.01531296826435902, 'model__subsample': 0.743588104890434, 'model__colsample_bytree': 0.9596242951154742, 'model__reg_alpha': 8.162931985414744, 'model__reg_lambda': 4.629455101222654, 'model__scale_pos_weight': 0.9084518369064275}. Best is trial 1 with value: 0.9126293995859214.
# [I 2024-03-28 15:39:14,935] Trial 3 finished with value: 0.8999704229517894 and parameters: {'model__n_estimators': 721, 'model__learning_rate': 0.08597743429037595, 'model__max_depth': 4, 'model__min_child_weight': 7, 'model__gamma': 0.06986013968289138, 'model__subsample': 0.2526968601132787, 'model__colsample_bytree': 0.4175917342197069, 'model__reg_alpha': 5.395223986524064, 'model__reg_lambda': 9.43390354120944, 'model__scale_pos_weight': 7.127742260770174}. Best is trial 1 with value: 0.9126293995859214.
# [I 2024-03-28 15:39:15,265] Trial 4 finished with value: 0.7944099378881988 and parameters: {'model__n_estimators': 236, 'model__learning_rate': 0.014446366736264437, 'model__max_depth': 7, 'model__min_child_weight': 5, 'model__gamma': 0.057022904003203, 'model__subsample': 0.023869884149049437, 'model__colsample_bytree': 0.8695592526040224, 'model__reg_alpha': 3.4947601890936766, 'model__reg_lambda': 6.972310439816163, 'model__scale_pos_weight': 5.512048365497515}. Best is trial 1 with value: 0.9126293995859214.
# [I 2024-03-28 15:39:15,632] Trial 5 finished with value: 0.9135758651286603 and parameters: {'model__n_estimators': 428, 'model__learning_rate': 0.03740118438952832, 'model__max_depth': 3, 'model__min_child_weight': 7, 'model__gamma': 0.08480330229973063, 'model__subsample': 0.46101946264204147, 'model__colsample_bytree': 0.773419915717162, 'model__reg_alpha': 9.94921299772255, 'model__reg_lambda': 9.983770572499981, 'model__scale_pos_weight': 4.537543821018941}. Best is trial 5 with value: 0.9135758651286603.
# [I 2024-03-28 15:39:15,952] Trial 6 finished with value: 0.6521739130434783 and parameters: {'model__n_estimators': 185, 'model__learning_rate': 0.09910093849080634, 'model__max_depth': 5, 'model__min_child_weight': 9, 'model__gamma': 0.0822044197895007, 'model__subsample': 0.34063058748754416, 'model__colsample_bytree': 0.36870384088913843, 'model__reg_alpha': 4.8271965322982116, 'model__reg_lambda': 9.94484853164614, 'model__scale_pos_weight': 0.35609446665108097}. Best is trial 5 with value: 0.9135758651286603.
# [I 2024-03-28 15:39:16,308] Trial 7 finished with value: 0.9116829340431826 and parameters: {'model__n_estimators': 275, 'model__learning_rate': 0.029341635081145505, 'model__max_depth': 3, 'model__min_child_weight': 7, 'model__gamma': 0.03204272780621803, 'model__subsample': 0.6559926932671475, 'model__colsample_bytree': 0.869958492917583, 'model__reg_alpha': 4.8961445156254655, 'model__reg_lambda': 6.900286827215132, 'model__scale_pos_weight': 2.5122153898724835}. Best is trial 5 with value: 0.9135758651286603.
# [I 2024-03-28 15:39:16,728] Trial 8 finished with value: 0.9099083111505473 and parameters: {'model__n_estimators': 572, 'model__learning_rate': 0.09288384803737888, 'model__max_depth': 7, 'model__min_child_weight': 1, 'model__gamma': 0.07401958343567328, 'model__subsample': 0.8704174518679025, 'model__colsample_bytree': 0.2161601535642885, 'model__reg_alpha': 6.62468664371008, 'model__reg_lambda': 6.725552038507259, 'model__scale_pos_weight': 7.132842583427166}. Best is trial 5 with value: 0.9135758651286603.
# [I 2024-03-28 15:39:17,137] Trial 9 finished with value: 0.8902987281869269 and parameters: {'model__n_estimators': 552, 'model__learning_rate': 0.03876837160962097, 'model__max_depth': 9, 'model__min_child_weight': 4, 'model__gamma': 0.0445367201796022, 'model__subsample': 0.6089004052034424, 'model__colsample_bytree': 0.08736397521042814, 'model__reg_alpha': 4.122473511815913, 'model__reg_lambda': 8.584276043443678, 'model__scale_pos_weight': 9.387302202073206}. Best is trial 5 with value: 0.9135758651286603.
# [I 2024-03-28 15:39:17,692] Trial 10 finished with value: 0.9126293995859214 and parameters: {'model__n_estimators': 991, 'model__learning_rate': 0.06469646108244043, 'model__max_depth': 10, 'model__min_child_weight': 10, 'model__gamma': 0.09465179450513683, 'model__subsample': 0.420116621513984, 'model__colsample_bytree': 0.6411351615375341, 'model__reg_alpha': 0.2689090137249428, 'model__reg_lambda': 1.9745859466056572, 'model__scale_pos_weight': 5.129784953838236}. Best is trial 5 with value: 0.9135758651286603.
# [I 2024-03-28 15:39:18,081] Trial 11 finished with value: 0.913309671694765 and parameters: {'model__n_estimators': 448, 'model__learning_rate': 0.06663743466818497, 'model__max_depth': 3, 'model__min_child_weight': 6, 'model__gamma': 0.09853494820670049, 'model__subsample': 0.5376008094147035, 'model__colsample_bytree': 0.6368577892731241, 'model__reg_alpha': 9.84277571956101, 'model__reg_lambda': 0.25095062304085847, 'model__scale_pos_weight': 3.5201910954288094}. Best is trial 5 with value: 0.9135758651286603.
# [I 2024-03-28 15:39:18,457] Trial 12 finished with value: 0.9176574977817215 and parameters: {'model__n_estimators': 400, 'model__learning_rate': 0.06406015143587748, 'model__max_depth': 3, 'model__min_child_weight': 4, 'model__gamma': 0.09552449128047337, 'model__subsample': 0.5071283754718994, 'model__colsample_bytree': 0.6513246369165515, 'model__reg_alpha': 9.869029074318073, 'model__reg_lambda': 0.09767284678048327, 'model__scale_pos_weight': 3.660876992129032}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:18,850] Trial 13 finished with value: 0.9022774327122152 and parameters: {'model__n_estimators': 368, 'model__learning_rate': 0.05261668899153124, 'model__max_depth': 5, 'model__min_child_weight': 3, 'model__gamma': 0.08708364086518552, 'model__subsample': 0.19088340837764572, 'model__colsample_bytree': 0.6526794636329349, 'model__reg_alpha': 9.556987329348736, 'model__reg_lambda': 2.7209242514357412, 'model__scale_pos_weight': 6.371843269124618}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:19,345] Trial 14 finished with value: 0.9139899438036084 and parameters: {'model__n_estimators': 668, 'model__learning_rate': 0.05513453426639105, 'model__max_depth': 6, 'model__min_child_weight': 5, 'model__gamma': 0.08491814185757773, 'model__subsample': 0.4485919537729693, 'model__colsample_bytree': 0.7512199640068111, 'model__reg_alpha': 8.413072131375046, 'model__reg_lambda': 5.183085584201667, 'model__scale_pos_weight': 3.937022712866913}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:19,793] Trial 15 finished with value: 0.9160307601301391 and parameters: {'model__n_estimators': 677, 'model__learning_rate': 0.07341510398001028, 'model__max_depth': 6, 'model__min_child_weight': 4, 'model__gamma': 0.09986594955579953, 'model__subsample': 0.7841195441273816, 'model__colsample_bytree': 0.5375321039105672, 'model__reg_alpha': 7.921077245973348, 'model__reg_lambda': 5.255214060895173, 'model__scale_pos_weight': 2.837077874025392}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:20,276] Trial 16 finished with value: 0.9160307601301391 and parameters: {'model__n_estimators': 855, 'model__learning_rate': 0.07692099207875036, 'model__max_depth': 6, 'model__min_child_weight': 3, 'model__gamma': 0.0994476091875776, 'model__subsample': 0.7859051195495199, 'model__colsample_bytree': 0.5188717134939907, 'model__reg_alpha': 7.911707326398309, 'model__reg_lambda': 5.076916897920513, 'model__scale_pos_weight': 2.090590471590079}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:20,761] Trial 17 finished with value: 0.9153504880212954 and parameters: {'model__n_estimators': 618, 'model__learning_rate': 0.07345670935713523, 'model__max_depth': 8, 'model__min_child_weight': 4, 'model__gamma': 0.061288858314837845, 'model__subsample': 0.6302101031195326, 'model__colsample_bytree': 0.5154322498444217, 'model__reg_alpha': 8.714374360616446, 'model__reg_lambda': 3.905383135705271, 'model__scale_pos_weight': 2.823940843110845}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:21,142] Trial 18 finished with value: 0.912363206152026 and parameters: {'model__n_estimators': 342, 'model__learning_rate': 0.05240656827145274, 'model__max_depth': 5, 'model__min_child_weight': 1, 'model__gamma': 0.03967360231919607, 'model__subsample': 0.84101792284756, 'model__colsample_bytree': 0.2443062846512245, 'model__reg_alpha': 6.847941393725106, 'model__reg_lambda': 1.4748979654195988, 'model__scale_pos_weight': 1.3129806557681076}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:21,741] Trial 19 finished with value: 0.914670215912452 and parameters: {'model__n_estimators': 849, 'model__learning_rate': 0.07971260687282894, 'model__max_depth': 10, 'model__min_child_weight': 3, 'model__gamma': 0.0927685636446988, 'model__subsample': 0.7179723385062424, 'model__colsample_bytree': 0.5706754236465956, 'model__reg_alpha': 2.66420120406621, 'model__reg_lambda': 6.014095902339976, 'model__scale_pos_weight': 5.927581894522648}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:22,277] Trial 20 finished with value: 0.9162969535640344 and parameters: {'model__n_estimators': 482, 'model__learning_rate': 0.06525979078777955, 'model__max_depth': 8, 'model__min_child_weight': 4, 'model__gamma': 0.07880061771118825, 'model__subsample': 0.545788958801164, 'model__colsample_bytree': 0.7187067728337874, 'model__reg_alpha': 8.958680050999149, 'model__reg_lambda': 8.24996710187285, 'model__scale_pos_weight': 8.356743844307928}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:22,787] Trial 21 finished with value: 0.9169772256728779 and parameters: {'model__n_estimators': 514, 'model__learning_rate': 0.06341363297422196, 'model__max_depth': 8, 'model__min_child_weight': 4, 'model__gamma': 0.0753010487810149, 'model__subsample': 0.5674024157134935, 'model__colsample_bytree': 0.710890994964403, 'model__reg_alpha': 9.026509874399999, 'model__reg_lambda': 8.26756776756085, 'model__scale_pos_weight': 9.956874560652572}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:23,263] Trial 22 finished with value: 0.9135758651286603 and parameters: {'model__n_estimators': 477, 'model__learning_rate': 0.0609477628139729, 'model__max_depth': 9, 'model__min_child_weight': 5, 'model__gamma': 0.07867088840533977, 'model__subsample': 0.5131930815583877, 'model__colsample_bytree': 0.7160883922832095, 'model__reg_alpha': 9.301386317095398, 'model__reg_lambda': 8.513055409065855, 'model__scale_pos_weight': 9.919232498174757}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:23,786] Trial 23 finished with value: 0.9101745045844425 and parameters: {'model__n_estimators': 510, 'model__learning_rate': 0.04550522157159465, 'model__max_depth': 8, 'model__min_child_weight': 2, 'model__gamma': 0.06410633429866433, 'model__subsample': 0.3280145233400077, 'model__colsample_bytree': 0.978546845493022, 'model__reg_alpha': 8.975334295809072, 'model__reg_lambda': 7.911748867950919, 'model__scale_pos_weight': 8.41329600027114}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:24,231] Trial 24 finished with value: 0.9156166814551907 and parameters: {'model__n_estimators': 331, 'model__learning_rate': 0.06130088171531595, 'model__max_depth': 9, 'model__min_child_weight': 6, 'model__gamma': 0.07776179318414354, 'model__subsample': 0.5735558734325249, 'model__colsample_bytree': 0.7042461078890637, 'model__reg_alpha': 7.426240379560474, 'model__reg_lambda': 7.756565717392123, 'model__scale_pos_weight': 8.605390857025121}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:24,690] Trial 25 finished with value: 0.9135758651286603 and parameters: {'model__n_estimators': 378, 'model__learning_rate': 0.06785019588244125, 'model__max_depth': 7, 'model__min_child_weight': 4, 'model__gamma': 0.08962544925598073, 'model__subsample': 0.36433077254524393, 'model__colsample_bytree': 0.7761325052569846, 'model__reg_alpha': 5.928948100031291, 'model__reg_lambda': 6.163929238512917, 'model__scale_pos_weight': 8.176154306114263}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:25,253] Trial 26 finished with value: 0.914670215912452 and parameters: {'model__n_estimators': 583, 'model__learning_rate': 0.04694892517945675, 'model__max_depth': 8, 'model__min_child_weight': 2, 'model__gamma': 0.06540083798072982, 'model__subsample': 0.6695774441190959, 'model__colsample_bytree': 0.6303353207103584, 'model__reg_alpha': 1.531164243571145, 'model__reg_lambda': 8.900758146293933, 'model__scale_pos_weight': 9.31452990828044}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:25,751] Trial 27 finished with value: 0.9169772256728779 and parameters: {'model__n_estimators': 507, 'model__learning_rate': 0.08038150835614558, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.07639390437093274, 'model__subsample': 0.5384461013527637, 'model__colsample_bytree': 0.45216882476091613, 'model__reg_alpha': 9.316422139654428, 'model__reg_lambda': 7.736944799192502, 'model__scale_pos_weight': 7.5458032063229314}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:26,139] Trial 28 finished with value: 0.8999704229517894 and parameters: {'model__n_estimators': 279, 'model__learning_rate': 0.08316483890860495, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.055839498388288375, 'model__subsample': 0.23475123614321275, 'model__colsample_bytree': 0.4269913063119137, 'model__reg_alpha': 9.97336472958801, 'model__reg_lambda': 7.472067692764769, 'model__scale_pos_weight': 7.184772203788599}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:26,556] Trial 29 finished with value: 0.9112688553682342 and parameters: {'model__n_estimators': 524, 'model__learning_rate': 0.07065928429605854, 'model__max_depth': 10, 'model__min_child_weight': 2, 'model__gamma': 0.04905143792003003, 'model__subsample': 0.9748357075191778, 'model__colsample_bytree': 0.26228431046828965, 'model__reg_alpha': 7.349686872824314, 'model__reg_lambda': 3.3343243708903785, 'model__scale_pos_weight': 7.660721694104327}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:26,885] Trial 30 finished with value: 0.9162969535640344 and parameters: {'model__n_estimators': 106, 'model__learning_rate': 0.08759237195997437, 'model__max_depth': 9, 'model__min_child_weight': 5, 'model__gamma': 0.0694165484939318, 'model__subsample': 0.40218783433194005, 'model__colsample_bytree': 0.44310806309141204, 'model__reg_alpha': 6.4676812358710905, 'model__reg_lambda': 4.355789267442612, 'model__scale_pos_weight': 6.250844275220694}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:27,352] Trial 31 finished with value: 0.9149364093463472 and parameters: {'model__n_estimators': 415, 'model__learning_rate': 0.056287492537172426, 'model__max_depth': 8, 'model__min_child_weight': 4, 'model__gamma': 0.0778537468926549, 'model__subsample': 0.5081053285494223, 'model__colsample_bytree': 0.8306658458241379, 'model__reg_alpha': 8.891558920969686, 'model__reg_lambda': 8.172019002054148, 'model__scale_pos_weight': 9.02406084568931}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:27,811] Trial 32 finished with value: 0.9176574977817215 and parameters: {'model__n_estimators': 500, 'model__learning_rate': 0.07811274722679909, 'model__max_depth': 7, 'model__min_child_weight': 3, 'model__gamma': 0.09117415494309863, 'model__subsample': 0.5837225509036631, 'model__colsample_bytree': 0.5939016453035373, 'model__reg_alpha': 9.171635579866795, 'model__reg_lambda': 8.923635085978102, 'model__scale_pos_weight': 9.803997161397206}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:28,284] Trial 33 finished with value: 0.9142561372375037 and parameters: {'model__n_estimators': 629, 'model__learning_rate': 0.08028576685263539, 'model__max_depth': 7, 'model__min_child_weight': 3, 'model__gamma': 0.09019045964919523, 'model__subsample': 0.5829149929194429, 'model__colsample_bytree': 0.4693211755544781, 'model__reg_alpha': 8.313516784005715, 'model__reg_lambda': 9.373622970768334, 'model__scale_pos_weight': 9.942336572282425}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:28,707] Trial 34 finished with value: 0.913309671694765 and parameters: {'model__n_estimators': 398, 'model__learning_rate': 0.09176673889847203, 'model__max_depth': 7, 'model__min_child_weight': 2, 'model__gamma': 0.09255068209526462, 'model__subsample': 0.716487113800762, 'model__colsample_bytree': 0.5862199279430977, 'model__reg_alpha': 9.350670863870027, 'model__reg_lambda': 9.13628127461599, 'model__scale_pos_weight': 7.769212047888168}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:29,190] Trial 35 finished with value: 0.9142561372375037 and parameters: {'model__n_estimators': 747, 'model__learning_rate': 0.07533351855738049, 'model__max_depth': 6, 'model__min_child_weight': 3, 'model__gamma': 0.010735316290804972, 'model__subsample': 0.47776293901342787, 'model__colsample_bytree': 0.3350534041447806, 'model__reg_alpha': 7.687132545772208, 'model__reg_lambda': 7.268186550794005, 'model__scale_pos_weight': 9.231614963783155}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:29,590] Trial 36 finished with value: 0.9119491274770778 and parameters: {'model__n_estimators': 472, 'model__learning_rate': 0.0856740353048365, 'model__max_depth': 4, 'model__min_child_weight': 1, 'model__gamma': 0.07151887098289558, 'model__subsample': 0.6469364128612429, 'model__colsample_bytree': 0.5840806479053273, 'model__reg_alpha': 8.36981524904217, 'model__reg_lambda': 6.235295874264437, 'model__scale_pos_weight': 4.272643370392849}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:29,933] Trial 37 finished with value: 0.881455190771961 and parameters: {'model__n_estimators': 192, 'model__learning_rate': 0.059721859276463916, 'model__max_depth': 8, 'model__min_child_weight': 6, 'model__gamma': 0.08246530067364105, 'model__subsample': 0.08664257397383018, 'model__colsample_bytree': 0.9154546394649286, 'model__reg_alpha': 9.466134633384193, 'model__reg_lambda': 1.0926374129885366, 'model__scale_pos_weight': 9.92535190322612}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:30,334] Trial 38 finished with value: 0.9092280390417037 and parameters: {'model__n_estimators': 315, 'model__learning_rate': 0.09960558594792968, 'model__max_depth': 7, 'model__min_child_weight': 5, 'model__gamma': 0.09474153212924799, 'model__subsample': 0.2796082662808397, 'model__colsample_bytree': 0.8156578550299587, 'model__reg_alpha': 8.62573571158539, 'model__reg_lambda': 9.59701204413219, 'model__scale_pos_weight': 4.836568817187063}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:30,821] Trial 39 finished with value: 0.9149364093463472 and parameters: {'model__n_estimators': 533, 'model__learning_rate': 0.014175231297913309, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.02238001358911694, 'model__subsample': 0.4793400513181007, 'model__colsample_bytree': 0.3610284664425633, 'model__reg_alpha': 7.1047623394985955, 'model__reg_lambda': 5.649140789310298, 'model__scale_pos_weight': 6.667023103552282}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:31,217] Trial 40 finished with value: 0.9156166814551907 and parameters: {'model__n_estimators': 434, 'model__learning_rate': 0.09245114910152318, 'model__max_depth': 5, 'model__min_child_weight': 4, 'model__gamma': 0.08687526029982053, 'model__subsample': 0.5728713364586328, 'model__colsample_bytree': 0.47603008978440536, 'model__reg_alpha': 9.948630534748537, 'model__reg_lambda': 8.77227202540182, 'model__scale_pos_weight': 5.546726059755187}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:31,690] Trial 41 finished with value: 0.9162969535640344 and parameters: {'model__n_estimators': 485, 'model__learning_rate': 0.06539767974129632, 'model__max_depth': 8, 'model__min_child_weight': 4, 'model__gamma': 0.07487886985398452, 'model__subsample': 0.5416606418717231, 'model__colsample_bytree': 0.6923362093186709, 'model__reg_alpha': 9.083330119345506, 'model__reg_lambda': 7.943932887756189, 'model__scale_pos_weight': 8.775479614806777}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:32,204] Trial 42 finished with value: 0.9142561372375037 and parameters: {'model__n_estimators': 617, 'model__learning_rate': 0.07077721721459047, 'model__max_depth': 8, 'model__min_child_weight': 5, 'model__gamma': 0.08179148535916743, 'model__subsample': 0.4138474588784655, 'model__colsample_bytree': 0.743432478312333, 'model__reg_alpha': 9.072259990419095, 'model__reg_lambda': 7.19017937327635, 'model__scale_pos_weight': 7.994751178809875}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:32,694] Trial 43 finished with value: 0.9126293995859214 and parameters: {'model__n_estimators': 590, 'model__learning_rate': 0.0808628133934642, 'model__max_depth': 7, 'model__min_child_weight': 4, 'model__gamma': 0.06780973729196729, 'model__subsample': 0.6837817331024879, 'model__colsample_bytree': 0.5912359804480531, 'model__reg_alpha': 7.96047054512384, 'model__reg_lambda': 8.47928486956641, 'model__scale_pos_weight': 9.493816327646398}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:33,179] Trial 44 finished with value: 0.9126293995859214 and parameters: {'model__n_estimators': 507, 'model__learning_rate': 0.0702624899195508, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.059355526110104646, 'model__subsample': 0.6090783711309158, 'model__colsample_bytree': 0.6684944287031455, 'model__reg_alpha': 9.511647365385066, 'model__reg_lambda': 6.692826084285139, 'model__scale_pos_weight': 8.822398322643606}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:33,685] Trial 45 finished with value: 0.9176574977817215 and parameters: {'model__n_estimators': 551, 'model__learning_rate': 0.024079607092561576, 'model__max_depth': 8, 'model__min_child_weight': 8, 'model__gamma': 0.08141537893100183, 'model__subsample': 0.545235625636811, 'model__colsample_bytree': 0.7928008418621528, 'model__reg_alpha': 8.641502546360437, 'model__reg_lambda': 9.989375664859036, 'model__scale_pos_weight': 7.251841979893889}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:34,210] Trial 46 finished with value: 0.9142561372375037 and parameters: {'model__n_estimators': 676, 'model__learning_rate': 0.03550388647530536, 'model__max_depth': 10, 'model__min_child_weight': 9, 'model__gamma': 0.08776615670489261, 'model__subsample': 0.4434878435770163, 'model__colsample_bytree': 0.8983542524962297, 'model__reg_alpha': 8.330033438203076, 'model__reg_lambda': 9.733509937210972, 'model__scale_pos_weight': 6.872974638429074}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:34,641] Trial 47 finished with value: 0.9115350488021295 and parameters: {'model__n_estimators': 556, 'model__learning_rate': 0.020271908006022257, 'model__max_depth': 4, 'model__min_child_weight': 8, 'model__gamma': 0.09614104649529848, 'model__subsample': 0.38086965080663426, 'model__colsample_bytree': 0.7986598095249963, 'model__reg_alpha': 4.250304242531026, 'model__reg_lambda': 9.197128966566318, 'model__scale_pos_weight': 7.325753315151107}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:34,993] Trial 48 finished with value: 0.9051464063886425 and parameters: {'model__n_estimators': 438, 'model__learning_rate': 0.02359997362947834, 'model__max_depth': 3, 'model__min_child_weight': 10, 'model__gamma': 0.07401701720024847, 'model__subsample': 0.5050610948489183, 'model__colsample_bytree': 0.11471798334450478, 'model__reg_alpha': 9.520189888482221, 'model__reg_lambda': 2.510326954084712, 'model__scale_pos_weight': 3.4825953886323995}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:35,444] Trial 49 finished with value: 0.9119491274770778 and parameters: {'model__n_estimators': 382, 'model__learning_rate': 0.04414447485889765, 'model__max_depth': 7, 'model__min_child_weight': 8, 'model__gamma': 0.08204844907516674, 'model__subsample': 0.6176481995045348, 'model__colsample_bytree': 0.8548703688285305, 'model__reg_alpha': 5.9080605858375455, 'model__reg_lambda': 9.889548006212456, 'model__scale_pos_weight': 9.512307059810574}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:35,902] Trial 50 finished with value: 0.9126293995859214 and parameters: {'model__n_estimators': 548, 'model__learning_rate': 0.027143699316488693, 'model__max_depth': 6, 'model__min_child_weight': 7, 'model__gamma': 0.0508507586974927, 'model__subsample': 0.7425025577971739, 'model__colsample_bytree': 0.543115179638639, 'model__reg_alpha': 7.629960142792344, 'model__reg_lambda': 8.926237209972037, 'model__scale_pos_weight': 5.487562264502678}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:36,343] Trial 51 finished with value: 0.9156166814551907 and parameters: {'model__n_estimators': 459, 'model__learning_rate': 0.06316170772725921, 'model__max_depth': 8, 'model__min_child_weight': 9, 'model__gamma': 0.0843148410458008, 'model__subsample': 0.562294189078065, 'model__colsample_bytree': 0.7411505516181528, 'model__reg_alpha': 8.691900987747806, 'model__reg_lambda': 8.415429495523304, 'model__scale_pos_weight': 7.5821647165858215}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:36,816] Trial 52 finished with value: 0.9135758651286603 and parameters: {'model__n_estimators': 486, 'model__learning_rate': 0.05671590150660699, 'model__max_depth': 8, 'model__min_child_weight': 4, 'model__gamma': 0.07835863277454809, 'model__subsample': 0.5373389896528762, 'model__colsample_bytree': 0.6311261739151788, 'model__reg_alpha': 9.621910069827674, 'model__reg_lambda': 7.691227970353334, 'model__scale_pos_weight': 8.976612882782419}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:37,319] Trial 53 finished with value: 0.9128955930198167 and parameters: {'model__n_estimators': 644, 'model__learning_rate': 0.07700098744844686, 'model__max_depth': 8, 'model__min_child_weight': 5, 'model__gamma': 0.09248353322461547, 'model__subsample': 0.45249834186481547, 'model__colsample_bytree': 0.6827802671463725, 'model__reg_alpha': 9.066402814283636, 'model__reg_lambda': 8.182075131205046, 'model__scale_pos_weight': 8.272830391991677}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:37,829] Trial 54 finished with value: 0.9099083111505473 and parameters: {'model__n_estimators': 581, 'model__learning_rate': 0.049874734256978664, 'model__max_depth': 7, 'model__min_child_weight': 6, 'model__gamma': 0.07449774915458156, 'model__subsample': 0.5998954632328584, 'model__colsample_bytree': 0.7753980467804432, 'model__reg_alpha': 9.947674047101554, 'model__reg_lambda': 9.556097386526142, 'model__scale_pos_weight': 9.541799064997425}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:38,288] Trial 55 finished with value: 0.9160307601301391 and parameters: {'model__n_estimators': 509, 'model__learning_rate': 0.0681146562322014, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.09756650168170405, 'model__subsample': 0.5452839991176516, 'model__colsample_bytree': 0.6261579282398315, 'model__reg_alpha': 8.709148172615814, 'model__reg_lambda': 6.899240983702333, 'model__scale_pos_weight': 3.0427235951504494}. Best is trial 12 with value: 0.9176574977817215.
# [I 2024-03-28 15:39:38,760] Trial 56 finished with value: 0.9183377698905649 and parameters: {'model__n_estimators': 406, 'model__learning_rate': 0.057730467335000965, 'model__max_depth': 9, 'model__min_child_weight': 2, 'model__gamma': 0.08978281093020471, 'model__subsample': 0.6683597213040051, 'model__colsample_bytree': 0.7280433003694241, 'model__reg_alpha': 9.154932053739994, 'model__reg_lambda': 9.187971448615553, 'model__scale_pos_weight': 7.99534078609156}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:39,192] Trial 57 finished with value: 0.9183377698905649 and parameters: {'model__n_estimators': 305, 'model__learning_rate': 0.058730461916914674, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.09026820720305789, 'model__subsample': 0.6984954425489437, 'model__colsample_bytree': 0.3918143981709664, 'model__reg_alpha': 8.030482386847074, 'model__reg_lambda': 9.994413941041643, 'model__scale_pos_weight': 6.041968546365917}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:39,678] Trial 58 finished with value: 0.9153504880212954 and parameters: {'model__n_estimators': 284, 'model__learning_rate': 0.042350789170236706, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.08961255996629926, 'model__subsample': 0.798466134229631, 'model__colsample_bytree': 0.9360035183136035, 'model__reg_alpha': 8.057889084041642, 'model__reg_lambda': 9.857481043068137, 'model__scale_pos_weight': 6.528342266741111}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:40,091] Trial 59 finished with value: 0.9156166814551907 and parameters: {'model__n_estimators': 229, 'model__learning_rate': 0.051797672779801934, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.09969268972043141, 'model__subsample': 0.6875457102161765, 'model__colsample_bytree': 0.3098518389053994, 'model__reg_alpha': 6.643397468417405, 'model__reg_lambda': 9.145167345381582, 'model__scale_pos_weight': 5.975585697040884}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:40,530] Trial 60 finished with value: 0.9153504880212954 and parameters: {'model__n_estimators': 360, 'model__learning_rate': 0.058450696517069176, 'model__max_depth': 10, 'model__min_child_weight': 2, 'model__gamma': 0.08613711607548276, 'model__subsample': 0.8696061979906403, 'model__colsample_bytree': 0.5571632840179285, 'model__reg_alpha': 8.535537539102664, 'model__reg_lambda': 9.406371649300544, 'model__scale_pos_weight': 4.552046863732451}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:40,975] Trial 61 finished with value: 0.9156166814551907 and parameters: {'model__n_estimators': 409, 'model__learning_rate': 0.048635119854877444, 'model__max_depth': 9, 'model__min_child_weight': 2, 'model__gamma': 0.09219068202005974, 'model__subsample': 0.6394640127832354, 'model__colsample_bytree': 0.4018138636033218, 'model__reg_alpha': 9.25977064237453, 'model__reg_lambda': 8.769149111906785, 'model__scale_pos_weight': 6.903220520449382}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:41,389] Trial 62 finished with value: 0.9119491274770778 and parameters: {'model__n_estimators': 319, 'model__learning_rate': 0.06243060272079197, 'model__max_depth': 9, 'model__min_child_weight': 2, 'model__gamma': 0.08363302751894348, 'model__subsample': 0.6535229533559622, 'model__colsample_bytree': 0.4994017382249419, 'model__reg_alpha': 9.61696634400265, 'model__reg_lambda': 0.35184998392764016, 'model__scale_pos_weight': 6.131970088819896}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:41,831] Trial 63 finished with value: 0.9160307601301391 and parameters: {'model__n_estimators': 244, 'model__learning_rate': 0.07386436991108189, 'model__max_depth': 9, 'model__min_child_weight': 1, 'model__gamma': 0.08968168538661243, 'model__subsample': 0.7058681849471139, 'model__colsample_bytree': 0.6018127784439092, 'model__reg_alpha': 0.0023830310563708323, 'model__reg_lambda': 9.905877019442382, 'model__scale_pos_weight': 7.498242289189062}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:42,266] Trial 64 finished with value: 0.9162969535640344 and parameters: {'model__n_estimators': 353, 'model__learning_rate': 0.05251995638282017, 'model__max_depth': 10, 'model__min_child_weight': 2, 'model__gamma': 0.09441727052722106, 'model__subsample': 0.7488297891438633, 'model__colsample_bytree': 0.39746385934243467, 'model__reg_alpha': 8.184022228023625, 'model__reg_lambda': 9.024851753732271, 'model__scale_pos_weight': 8.027232877472368}. Best is trial 56 with value: 0.9183377698905649.
# [I 2024-03-28 15:39:42,739] Trial 65 finished with value: 0.9190180419994085 and parameters: {'model__n_estimators': 448, 'model__learning_rate': 0.0958448964179838, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.08042533054517659, 'model__subsample': 0.5928393560522548, 'model__colsample_bytree': 0.6676593584243565, 'model__reg_alpha': 2.9358924105465674, 'model__reg_lambda': 9.4049766039414, 'model__scale_pos_weight': 5.57605012539502}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:43,168] Trial 66 finished with value: 0.9103223898254955 and parameters: {'model__n_estimators': 153, 'model__learning_rate': 0.03533301010271539, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.08054224319749617, 'model__subsample': 0.7566801856449367, 'model__colsample_bytree': 0.6644238878939425, 'model__reg_alpha': 2.234486411891711, 'model__reg_lambda': 9.26292148710649, 'model__scale_pos_weight': 5.762271124910961}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:43,599] Trial 67 finished with value: 0.9116829340431826 and parameters: {'model__n_estimators': 443, 'model__learning_rate': 0.08934587910411587, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.0968800466907819, 'model__subsample': 0.5923997031524728, 'model__colsample_bytree': 0.7323443867452797, 'model__reg_alpha': 3.1334736235787517, 'model__reg_lambda': 9.97760240397291, 'model__scale_pos_weight': 1.7438246270980438}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:44,015] Trial 68 finished with value: 0.9096421177166519 and parameters: {'model__n_estimators': 302, 'model__learning_rate': 0.09631625766884584, 'model__max_depth': 6, 'model__min_child_weight': 2, 'model__gamma': 0.0860138963428683, 'model__subsample': 0.6328777592645591, 'model__colsample_bytree': 0.7968486601581171, 'model__reg_alpha': 1.0159533648953218, 'model__reg_lambda': 9.531648474306154, 'model__scale_pos_weight': 5.106413833706184}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:44,477] Trial 69 finished with value: 0.9153504880212954 and parameters: {'model__n_estimators': 395, 'model__learning_rate': 0.04073890359641643, 'model__max_depth': 8, 'model__min_child_weight': 3, 'model__gamma': 0.08884387942044723, 'model__subsample': 0.4908152636279638, 'model__colsample_bytree': 0.6971383422112609, 'model__reg_alpha': 5.014591452682063, 'model__reg_lambda': 8.66583848953121, 'model__scale_pos_weight': 4.184197946739627}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:44,833] Trial 70 finished with value: 0.8913043478260869 and parameters: {'model__n_estimators': 425, 'model__learning_rate': 0.058946209558066634, 'model__max_depth': 4, 'model__min_child_weight': 2, 'model__gamma': 0.039148706662579066, 'model__subsample': 0.7974929212036285, 'model__colsample_bytree': 0.6154721341378347, 'model__reg_alpha': 3.716999622829698, 'model__reg_lambda': 3.7126862510567187, 'model__scale_pos_weight': 0.2788334574937128}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:45,287] Trial 71 finished with value: 0.9169772256728779 and parameters: {'model__n_estimators': 535, 'model__learning_rate': 0.08416152793593373, 'model__max_depth': 9, 'model__min_child_weight': 4, 'model__gamma': 0.07170217986561137, 'model__subsample': 0.6712278467645089, 'model__colsample_bytree': 0.46950563058098777, 'model__reg_alpha': 9.239010997618971, 'model__reg_lambda': 8.042764993194757, 'model__scale_pos_weight': 5.4190105388766385}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:45,740] Trial 72 finished with value: 0.9149364093463472 and parameters: {'model__n_estimators': 464, 'model__learning_rate': 0.05498745261555717, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.07663954175100439, 'model__subsample': 0.5247317459546882, 'model__colsample_bytree': 0.521260383943615, 'model__reg_alpha': 9.655612809852975, 'model__reg_lambda': 9.566983048709476, 'model__scale_pos_weight': 7.015815189668237}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:46,328] Trial 73 finished with value: 0.9183377698905649 and parameters: {'model__n_estimators': 985, 'model__learning_rate': 0.0965471828847962, 'model__max_depth': 9, 'model__min_child_weight': 4, 'model__gamma': 0.08026495774077588, 'model__subsample': 0.5669312067324933, 'model__colsample_bytree': 0.7593835911044403, 'model__reg_alpha': 8.761572244475781, 'model__reg_lambda': 8.368757959996383, 'model__scale_pos_weight': 7.862302606003745}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:46,894] Trial 74 finished with value: 0.9162969535640344 and parameters: {'model__n_estimators': 972, 'model__learning_rate': 0.09613134300850838, 'model__max_depth': 8, 'model__min_child_weight': 4, 'model__gamma': 0.09101925038013123, 'model__subsample': 0.5644576008655628, 'model__colsample_bytree': 0.8831706832100152, 'model__reg_alpha': 8.818085684673543, 'model__reg_lambda': 1.0191855509113181, 'model__scale_pos_weight': 8.626127569564133}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:47,452] Trial 75 finished with value: 0.9139899438036084 and parameters: {'model__n_estimators': 916, 'model__learning_rate': 0.09561818728583868, 'model__max_depth': 10, 'model__min_child_weight': 5, 'model__gamma': 0.08423568965606414, 'model__subsample': 0.6001309707123201, 'model__colsample_bytree': 0.7665261694912906, 'model__reg_alpha': 7.129491995020855, 'model__reg_lambda': 4.798154413397478, 'model__scale_pos_weight': 6.394699406310534}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:47,958] Trial 76 finished with value: 0.913309671694765 and parameters: {'model__n_estimators': 733, 'model__learning_rate': 0.08822281816502044, 'model__max_depth': 9, 'model__min_child_weight': 4, 'model__gamma': 0.09450276067986753, 'model__subsample': 0.4672508553857916, 'model__colsample_bytree': 0.6598925056804178, 'model__reg_alpha': 8.53526501568421, 'model__reg_lambda': 8.30964850062067, 'model__scale_pos_weight': 4.728603337398613}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:48,503] Trial 77 finished with value: 0.9162969535640344 and parameters: {'model__n_estimators': 809, 'model__learning_rate': 0.010138635193593162, 'model__max_depth': 5, 'model__min_child_weight': 3, 'model__gamma': 0.06608338443023679, 'model__subsample': 0.5121247631305386, 'model__colsample_bytree': 0.7097230577100953, 'model__reg_alpha': 7.735173571141749, 'model__reg_lambda': 8.813349315919407, 'model__scale_pos_weight': 7.834638479292499}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:49,049] Trial 78 finished with value: 0.913309671694765 and parameters: {'model__n_estimators': 709, 'model__learning_rate': 0.06724223133202789, 'model__max_depth': 8, 'model__min_child_weight': 7, 'model__gamma': 0.08034316864141683, 'model__subsample': 0.6271863826592298, 'model__colsample_bytree': 0.8357130112931056, 'model__reg_alpha': 2.2637974174927367, 'model__reg_lambda': 9.329985141370093, 'model__scale_pos_weight': 9.708142814119293}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:49,496] Trial 79 finished with value: 0.9092280390417037 and parameters: {'model__n_estimators': 260, 'model__learning_rate': 0.06302343712160104, 'model__max_depth': 7, 'model__min_child_weight': 4, 'model__gamma': 0.08846216583130775, 'model__subsample': 0.4333944602800389, 'model__colsample_bytree': 0.8041461605903442, 'model__reg_alpha': 8.813005147773833, 'model__reg_lambda': 8.586708596596187, 'model__scale_pos_weight': 9.13679554597277}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:49,984] Trial 80 finished with value: 0.9153504880212954 and parameters: {'model__n_estimators': 333, 'model__learning_rate': 0.09057243432597575, 'model__max_depth': 8, 'model__min_child_weight': 1, 'model__gamma': 0.07996962016222317, 'model__subsample': 0.714302157125915, 'model__colsample_bytree': 0.7583024214101587, 'model__reg_alpha': 4.461825376486743, 'model__reg_lambda': 9.034890822800888, 'model__scale_pos_weight': 7.282358750120973}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:50,434] Trial 81 finished with value: 0.9169772256728779 and parameters: {'model__n_estimators': 489, 'model__learning_rate': 0.07815341133383256, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.0761968957486507, 'model__subsample': 0.5728980409408897, 'model__colsample_bytree': 0.44633102554846626, 'model__reg_alpha': 9.278124864950431, 'model__reg_lambda': 9.62949810858798, 'model__scale_pos_weight': 6.711850796140023}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:50,854] Trial 82 finished with value: 0.9020112392783202 and parameters: {'model__n_estimators': 602, 'model__learning_rate': 0.09408369913696725, 'model__max_depth': 3, 'model__min_child_weight': 3, 'model__gamma': 0.06978087250153676, 'model__subsample': 0.48578533394233697, 'model__colsample_bytree': 0.7264759914908581, 'model__reg_alpha': 9.83558002418669, 'model__reg_lambda': 7.5017910219975, 'model__scale_pos_weight': 8.42869781855781}. Best is trial 65 with value: 0.9190180419994085.
# [I 2024-03-28 15:39:51,340] Trial 83 finished with value: 0.9196983141082519 and parameters: {'model__n_estimators': 560, 'model__learning_rate': 0.08147880972543659, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.07308435953343387, 'model__subsample': 0.551296973520393, 'model__colsample_bytree': 0.6499015800571791, 'model__reg_alpha': 8.386404011946796, 'model__reg_lambda': 4.333314223121343, 'model__scale_pos_weight': 5.222153010780475}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:51,785] Trial 84 finished with value: 0.9139899438036084 and parameters: {'model__n_estimators': 375, 'model__learning_rate': 0.08634752421087906, 'model__max_depth': 10, 'model__min_child_weight': 4, 'model__gamma': 0.07215392372786533, 'model__subsample': 0.6551148829211102, 'model__colsample_bytree': 0.6546428474505471, 'model__reg_alpha': 7.4217636720399, 'model__reg_lambda': 3.0478258707681363, 'model__scale_pos_weight': 5.173199265962605}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:52,250] Trial 85 finished with value: 0.9160307601301391 and parameters: {'model__n_estimators': 555, 'model__learning_rate': 0.09856707578206789, 'model__max_depth': 9, 'model__min_child_weight': 2, 'model__gamma': 0.08559982302812108, 'model__subsample': 0.5582294254473532, 'model__colsample_bytree': 0.6719973712942937, 'model__reg_alpha': 8.227145676254205, 'model__reg_lambda': 4.188238993053206, 'model__scale_pos_weight': 3.905772433332384}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:52,692] Trial 86 finished with value: 0.9190180419994085 and parameters: {'model__n_estimators': 414, 'model__learning_rate': 0.08243994856080532, 'model__max_depth': 8, 'model__min_child_weight': 2, 'model__gamma': 0.062424933577016416, 'model__subsample': 0.5908741060879336, 'model__colsample_bytree': 0.5638943863420709, 'model__reg_alpha': 8.917502627873706, 'model__reg_lambda': 1.7332470743086341, 'model__scale_pos_weight': 5.669440469839379}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:53,133] Trial 87 finished with value: 0.9153504880212954 and parameters: {'model__n_estimators': 411, 'model__learning_rate': 0.08322904442367915, 'model__max_depth': 9, 'model__min_child_weight': 2, 'model__gamma': 0.06377646503640355, 'model__subsample': 0.6936632113918825, 'model__colsample_bytree': 0.6100032653589559, 'model__reg_alpha': 7.8523889451475215, 'model__reg_lambda': 2.1904942321466625, 'model__scale_pos_weight': 5.818281849135476}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:53,555] Trial 88 finished with value: 0.914670215912452 and parameters: {'model__n_estimators': 453, 'model__learning_rate': 0.08204624227546224, 'model__max_depth': 6, 'model__min_child_weight': 2, 'model__gamma': 0.0618936130465147, 'model__subsample': 0.6122066628753247, 'model__colsample_bytree': 0.5718549573121264, 'model__reg_alpha': 8.50837673014684, 'model__reg_lambda': 1.7494638949089878, 'model__scale_pos_weight': 5.634861103354957}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:53,981] Trial 89 finished with value: 0.9139899438036084 and parameters: {'model__n_estimators': 388, 'model__learning_rate': 0.07462080968789561, 'model__max_depth': 8, 'model__min_child_weight': 8, 'model__gamma': 0.08194643859362881, 'model__subsample': 0.5882720238268477, 'model__colsample_bytree': 0.6441221956538123, 'model__reg_alpha': 8.952938090537897, 'model__reg_lambda': 0.11886809849705769, 'model__scale_pos_weight': 5.2312219224870375}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:54,574] Trial 90 finished with value: 0.9183377698905649 and parameters: {'model__n_estimators': 911, 'model__learning_rate': 0.0715778198884433, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.09555053961742274, 'model__subsample': 0.524472741048104, 'model__colsample_bytree': 0.6897033339377262, 'model__reg_alpha': 9.720222644417138, 'model__reg_lambda': 0.5522637006860537, 'model__scale_pos_weight': 6.151955415285195}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:55,166] Trial 91 finished with value: 0.913309671694765 and parameters: {'model__n_estimators': 943, 'model__learning_rate': 0.07218697474922192, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.09578065091998042, 'model__subsample': 0.5181778598775995, 'model__colsample_bytree': 0.6892744945006333, 'model__reg_alpha': 9.783285515464247, 'model__reg_lambda': 0.7303450752574608, 'model__scale_pos_weight': 6.134457196919534}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:55,726] Trial 92 finished with value: 0.9190180419994085 and parameters: {'model__n_estimators': 926, 'model__learning_rate': 0.07836722178425859, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.052208451978779026, 'model__subsample': 0.5417161427553289, 'model__colsample_bytree': 0.5589537687807906, 'model__reg_alpha': 9.110255520972661, 'model__reg_lambda': 1.1991923137186395, 'model__scale_pos_weight': 4.853255236253237}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:56,300] Trial 93 finished with value: 0.9196983141082519 and parameters: {'model__n_estimators': 902, 'model__learning_rate': 0.06923944422059672, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.043301206418885206, 'model__subsample': 0.49186420111315016, 'model__colsample_bytree': 0.5357977778806075, 'model__reg_alpha': 9.183610876033294, 'model__reg_lambda': 1.0811098087060678, 'model__scale_pos_weight': 4.9250828074663975}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:56,864] Trial 94 finished with value: 0.9190180419994085 and parameters: {'model__n_estimators': 884, 'model__learning_rate': 0.06927299713159979, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.051229381710866904, 'model__subsample': 0.4988875673021842, 'model__colsample_bytree': 0.5424280315424106, 'model__reg_alpha': 9.423920835412558, 'model__reg_lambda': 1.3517148182218284, 'model__scale_pos_weight': 4.855001655060492}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:57,406] Trial 95 finished with value: 0.9190180419994085 and parameters: {'model__n_estimators': 896, 'model__learning_rate': 0.07714014190235044, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.05101081149609737, 'model__subsample': 0.4983260390100108, 'model__colsample_bytree': 0.4874680959606632, 'model__reg_alpha': 9.381307189414656, 'model__reg_lambda': 1.2695346015538713, 'model__scale_pos_weight': 4.879555838980825}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:57,977] Trial 96 finished with value: 0.9183377698905649 and parameters: {'model__n_estimators': 857, 'model__learning_rate': 0.0761220300509654, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.049316946314006266, 'model__subsample': 0.41499442622396737, 'model__colsample_bytree': 0.5005362518612791, 'model__reg_alpha': 9.43754761027875, 'model__reg_lambda': 1.38126804503478, 'model__scale_pos_weight': 4.850016713929148}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:58,564] Trial 97 finished with value: 0.9190180419994085 and parameters: {'model__n_estimators': 875, 'model__learning_rate': 0.06951461391750581, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.05287921232633101, 'model__subsample': 0.49931142659141725, 'model__colsample_bytree': 0.5359266410844479, 'model__reg_alpha': 8.975768921185335, 'model__reg_lambda': 1.720310159434096, 'model__scale_pos_weight': 4.350538548307842}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:59,125] Trial 98 finished with value: 0.9183377698905649 and parameters: {'model__n_estimators': 899, 'model__learning_rate': 0.06941639150435644, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.05298230913261097, 'model__subsample': 0.4997993365969265, 'model__colsample_bytree': 0.5208362919048596, 'model__reg_alpha': 9.02654496276407, 'model__reg_lambda': 1.6854803032892869, 'model__scale_pos_weight': 4.384709305038991}. Best is trial 83 with value: 0.9196983141082519.
# [I 2024-03-28 15:39:59,696] Trial 99 finished with value: 0.9176574977817215 and parameters: {'model__n_estimators': 881, 'model__learning_rate': 0.06529344631646686, 'model__max_depth': 10, 'model__min_child_weight': 1, 'model__gamma': 0.04064727611769428, 'model__subsample': 0.3882859073347822, 'model__colsample_bytree': 0.5460265796473471, 'model__reg_alpha': 8.331321979178384, 'model__reg_lambda': 1.2435338924246562, 'model__scale_pos_weight': 4.622376853711536}. Best is trial 83 with value: 0.9196983141082519.

# %%
print("Best parameters=", study.best_params, end = "\n\n")
print("Best score=", round(study.best_value, 3), end = "\n\n")
print("Best model=", study.best_trial)
# Out:
# Best parameters= {'model__n_estimators': 560, 'model__learning_rate': 0.08147880972543659, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.07308435953343387, 'model__subsample': 0.551296973520393, 'model__colsample_bytree': 0.6499015800571791, 'model__reg_alpha': 8.386404011946796, 'model__reg_lambda': 4.333314223121343, 'model__scale_pos_weight': 5.222153010780475}
#
# Best score= 0.92
#
# Best model= FrozenTrial(number=83, state=1, values=[0.9196983141082519], datetime_start=datetime.datetime(2024, 3, 28, 15, 39, 50, 854679), datetime_complete=datetime.datetime(2024, 3, 28, 15, 39, 51, 340326), params={'model__n_estimators': 560, 'model__learning_rate': 0.08147880972543659, 'model__max_depth': 9, 'model__min_child_weight': 3, 'model__gamma': 0.07308435953343387, 'model__subsample': 0.551296973520393, 'model__colsample_bytree': 0.6499015800571791, 'model__reg_alpha': 8.386404011946796, 'model__reg_lambda': 4.333314223121343, 'model__scale_pos_weight': 5.222153010780475}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'model__n_estimators': IntDistribution(high=1000, log=False, low=100, step=1), 'model__learning_rate': FloatDistribution(high=0.1, log=False, low=0.01, step=None), 'model__max_depth': IntDistribution(high=10, log=False, low=3, step=1), 'model__min_child_weight': IntDistribution(high=10, log=False, low=1, step=1), 'model__gamma': FloatDistribution(high=0.1, log=False, low=0.01, step=None), 'model__subsample': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'model__colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'model__reg_alpha': FloatDistribution(high=10.0, log=False, low=1e-05, step=None), 'model__reg_lambda': FloatDistribution(high=10.0, log=False, low=1e-05, step=None), 'model__scale_pos_weight': FloatDistribution(high=10.0, log=False, low=1e-05, step=None)}, trial_id=83, value=None)

# %%
# Re-fit model with the best parameters
pipeline.set_params(**study.best_params)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('feature_engineering',
#                                                   ColumnTransformer(transformers=[('total_net_minutes',
#                                                                                    FunctionTransformer(func=<function get_total_net_minutes at 0x16383fa60>),
#                                                                                    ['total_day_minutes',
#                                                                                     'total_eve_minutes',
#                                                                                     'total_night_minutes']),
#                                                                                   ('total_net_calls',
#                                                                                    FunctionTransformer(func=<function get_total_net_calls at...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.08147880972543659, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=9,
#                                max_leaves=None, min_child_weight=3, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=560, n_jobs=4,
#                                num_parallel_tree=None, random_state=0, ...))])

# %%
predictions = pipeline.predict(X_test)

# %%
# Evaluate the performance of the final model
print("Accuracy:", round(accuracy_score(y_test, predictions), 3))
print("AUC:", round(roc_auc_score(y_test, predictions), 3))
# Out:
# Accuracy: 0.975
# AUC: 0.92

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       735
#            1       0.97      0.84      0.90       115
#
#     accuracy                           0.98       850
#    macro avg       0.97      0.92      0.94       850
# weighted avg       0.98      0.98      0.97       850

# %% [markdown]
# **Conclusion:** We get back an accuracy score of 97.6% on the test dataset, with an AUC score of 0.92. The tuned model is performing better than the untuned model and we are now able to predict with very high accuracy which of customers are going to churn and which will be retained, purely based on their tenure, call plan, call charges and usage, and how often they needed to contact customer service.
